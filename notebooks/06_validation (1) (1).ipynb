# %% [markdown]
# # Notebook 06 - Validation Against Manual Excel
#
# **Goal:** Compare automated New Bucket assignments (from `archetype_mapping.csv`)
# against the analyst's manual assignments (from `Bucket_map` sheet in the Excel file).
#
# **Join key:** `(Division, Portal, Size, bucket_min)` where `bucket_min = floor(manual_min / 100) * 100`
#
# **Metrics:** % rows correctly assigned, % of qty correctly assigned, per-segment breakdown.

# %%
import pandas as pd
import numpy as np
import sys, os
import warnings
warnings.filterwarnings('ignore')

# Robust src path - works whether run manually or via papermill
_src_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'src'))
if _src_path not in sys.path:
    sys.path.insert(0, _src_path)
from config import *

OUT      = OUT_PATH   # comes from config import *
RAW_PATH = f'../{VALIDATION_FILE}'

mapping = pd.read_csv(f'{OUT}archetype_mapping.csv')
print(f'archetype_mapping : {mapping.shape}')
print('Columns:', mapping.columns.tolist())

# %% [markdown]
# ## 1. Load Ground Truth from Excel (`Bucket_map` sheet)

# %%
bm_raw = pd.read_excel(RAW_PATH, sheet_name=VALIDATION_SHEET)
print(f'Bucket_map raw shape : {bm_raw.shape}')
print('Years present        :', sorted(bm_raw['year'].unique()))

# Exclude 2023 (same business rule as our pipeline)
bm = bm_raw[bm_raw['year'] >= 2024].copy()
print(f'After excluding 2023 : {bm.shape}')

# Build bucket_min aligned to 100-unit bins (floor(min/100)*100)
if VALIDATION_JOIN == 'floor_100':
    bm['bucket_min'] = (bm[VALIDATION_MIN_COL] // 100) * 100
elif VALIDATION_JOIN == 'parse_string':
    bm['bucket_min'] = bm[VALIDATION_MIN_COL].str.split('-').str[0].astype(int)

# Deduplicate: one ground-truth New Bucket per (Division, Portal, Size, bucket_min)
# Detect qty column: EC uses 'Total_Pcs', TT uses 'qty'
_qty_col = next((c for c in bm.columns if c.lower() in ('qty', 'total_pcs', 'quantity')), None)
if _qty_col is None:
    print(f'WARNING: No qty column found. Available: {bm.columns.tolist()}')
    bm['_qty'] = 0
    _qty_col = '_qty'
else:
    print(f'Using qty column: {_qty_col!r}')

gt = (bm.groupby(['Division', 'Portal', 'Size', 'bucket_min'])
        .agg(gt_New_Bucket=('New Bucket', 'first'),
             gt_key=(GT_KEY_COL, 'first'),
             gt_qty=(_qty_col, 'sum'))
        .reset_index())

print(f'Ground truth unique (seg, bucket_min) rows: {len(gt)}')
print(gt.head(5).to_string(index=False))
# Out:
# Bucket_map raw shape : (8297, 14)
# Years present        : [np.int64(2023), np.int64(2024), np.int64(2025)]
# After excluding 2023 : (5725, 14)
# Ground truth unique (seg, bucket_min) rows: 574
# Division  Portal   Size  bucket_min  gt_New_Bucket       gt_key  gt_qty
#       BP       1 Single           0              1 BPTT11Single  144049
#       BP       1 Single         500              2 BPTT12Single  167249
#       BP       1 Single         600              3 BPTT13Single  130747
#       BP       1 Single         700              4 BPTT14Single  104946
#       BP       1 Single         800              4 BPTT14Single   90213

# %% [markdown]
# ## 2. Join Automated vs Ground Truth

# %%
# Our mapping: Division, Portal, Size, bucket_min, New_Bucket, archetype_key, total_qty
our = mapping[['Division','Portal','Size','bucket_min','New_Bucket','archetype_key','total_qty']].copy()

merged = our.merge(gt[['Division','Portal','Size','bucket_min',
                        'gt_New_Bucket','gt_key','gt_qty']],
                   on=['Division','Portal','Size','bucket_min'],
                   how='left')

n_unmatched = merged['gt_New_Bucket'].isna().sum()
print(f'Rows in our mapping          : {len(our)}')
print(f'Rows matched to ground truth : {len(merged) - n_unmatched}')
print(f'Rows with no GT match        : {n_unmatched}')
if n_unmatched:
    print('  (These are extrapolated buckets beyond GT range - expected)')
# Out:
# Rows in our mapping          : 2142
# Rows matched to ground truth : 568
# Rows with no GT match        : 1574
#   (These are extrapolated buckets beyond GT range — expected)

# %% [markdown]
# ## 3. Compute Match Metrics

# %%
# Only evaluate rows that have a ground truth match
eval_df = merged.dropna(subset=['gt_New_Bucket']).copy()
eval_df['gt_New_Bucket'] = eval_df['gt_New_Bucket'].astype(int)
eval_df['match'] = eval_df['New_Bucket'] == eval_df['gt_New_Bucket']

n_total  = len(eval_df)
n_match  = eval_df['match'].sum()
qty_total = eval_df['total_qty'].sum()
qty_match = eval_df.loc[eval_df['match'], 'total_qty'].sum()

print('=== OVERALL VALIDATION RESULTS ===')
print(f'Rows evaluated       : {n_total}')
print(f'Rows correct         : {n_match}  ({n_match/n_total:.1%})')
print(f'Qty covered (correct): {qty_match:,.0f} / {qty_total:,.0f}  ({qty_match/qty_total:.1%})')
# Out:
# === OVERALL VALIDATION RESULTS ===
# Rows evaluated       : 568
# Rows correct         : 288  (50.7%)
# Qty covered (correct): 1,118,116 / 4,214,755  (26.5%)

# %% [markdown]
# ## 4. Per-Segment Breakdown

# %%
seg_res = (eval_df.groupby(['Division','Portal','Size'])
           .apply(lambda g: pd.Series({
               'buckets_evaluated' : len(g),
               'buckets_correct'   : g['match'].sum(),
               'pct_correct'       : f"{g['match'].mean():.1%}",
               'qty_correct_pct'   : f"{g.loc[g['match'],'total_qty'].sum() / g['total_qty'].sum():.1%}"
               if g['total_qty'].sum() > 0 else 'N/A'
           }))
           .reset_index())

print('=== PER-SEGMENT VALIDATION ===')
print(seg_res.to_string(index=False))
# Out:
# === PER-SEGMENT VALIDATION ===
# Division  Portal   Size  buckets_evaluated  buckets_correct pct_correct qty_correct_pct
#       BP       1 Single                 20                8       40.0%           11.2%
#       BS       1 Single                 10                1       10.0%            0.0%
#       DF       1     DF                 25               12       48.0%            8.4%
#       DF       1    DFT                 21               10       47.6%           17.2%
#       HL       1  CABIN                 50               10       20.0%           58.0%
#       HL       1  LARGE                 61               21       34.4%           17.2%
#       HL       1 MEDIUM                 59               14       23.7%           29.2%
#       HL       1    SO2                 53               35       66.0%           28.5%
#       HL       1    SO3                 61               46       75.4%           18.8%
#       SL       1  CABIN                 45               28       62.2%           48.1%
#       SL       1  LARGE                 48               21       43.8%           35.4%
#       SL       1 MEDIUM                 47               24       51.1%           26.5%
#       SL       1    SO2                 33               28       84.8%           37.2%
#       SL       1    SO3                 35               30       85.7%           33.2%

# %% [markdown]
# ## 5. Mismatch Detail (for review)

# %%
mismatches = eval_df[~eval_df['match']].copy()
mismatches['segment'] = mismatches['Division'] + '_' + mismatches['Portal'].astype(str) + '_' + mismatches['Size']

print(f'Total mismatched bucket-rows: {len(mismatches)}')
print()

if len(mismatches) > 0:
    print('=== MISMATCH DETAIL ===')
    cols = ['segment','bucket_min','New_Bucket','gt_New_Bucket','archetype_key','gt_key','total_qty']
    print(mismatches[cols].sort_values(['segment','bucket_min']).to_string(index=False))
else:
    print('OK Perfect match - zero mismatches!')
# Out:
# Total mismatched bucket-rows: 280
#
# === MISMATCH DETAIL ===
#     segment  bucket_min  New_Bucket  gt_New_Bucket archetype_key        gt_key  total_qty
# BP_1_Single         500           4              2  BPTT14Single  BPTT12Single     152707
# BP_1_Single         600           4              3  BPTT14Single  BPTT13Single     121192
# BP_1_Single         700           5              4  BPTT15Single  BPTT14Single     116195
# BP_1_Single         800           6              4  BPTT16Single  BPTT14Single      91707
# BP_1_Single         900           7              4  BPTT17Single  BPTT14Single      53848
# BP_1_Single        1000           7              5  BPTT17Single  BPTT15Single     106065
# BP_1_Single        1100           7              6  BPTT17Single  BPTT16Single      79810
# BP_1_Single        1300           7              8  BPTT17Single  BPTT18Single      26835
# BP_1_Single        1400           7              8  BPTT17Single  BPTT18Single      38434
# BP_1_Single        1500           7              9  BPTT17Single  BPTT19Single      32668
# BP_1_Single        2500          10              9 BPTT110Single  BPTT19Single         76
# BP_1_Single        3000          10              9 BPTT110Single  BPTT19Single       1469
# BS_1_Single        1000           2              3  BSTT12Single  BSTT13Single         19
# BS_1_Single        1500           3              4  BSTT13Single  BSTT14Single          0
# BS_1_Single        2000           6              5  BSTT16Single  BSTT15Single          4
# BS_1_Single        2500          10              6 BSTT110Single  BSTT16Single        535
# BS_1_Single        3000          10              7 BSTT110Single  BSTT17Single          0
# BS_1_Single        3500          11              8 BSTT111Single  BSTT18Single         49
# BS_1_Single        4000          11              9 BSTT111Single  BSTT19Single         43
# BS_1_Single        4500          11             10 BSTT111Single BSTT110Single          0
# BS_1_Single        6000          12             11 BSTT112Single BSTT111Single          0
#     DF_1_DF         500           1              2      DFTT11DF      DFTT12DF     135195
#     DF_1_DF         600           1              3      DFTT11DF      DFTT13DF      13160
#     DF_1_DF         700           1              3      DFTT11DF      DFTT13DF      16447
#     DF_1_DF         800           1              4      DFTT11DF      DFTT14DF         35
#     DF_1_DF         900           2              4      DFTT12DF      DFTT14DF       7826
#     DF_1_DF        1000           3              4      DFTT13DF      DFTT14DF       3684
#     DF_1_DF        1100           3              5      DFTT13DF      DFTT15DF        813
#     DF_1_DF        1200           4              5      DFTT14DF      DFTT15DF       8827
#     DF_1_DF        1400           5              6      DFTT15DF      DFTT16DF        168
#     DF_1_DF        1500           5              6      DFTT15DF      DFTT16DF        325
#     DF_1_DF        2000           5              6      DFTT15DF      DFTT16DF         47
#     DF_1_DF        2500           5              6      DFTT15DF      DFTT16DF          0
#     DF_1_DF        3000           5              6      DFTT15DF      DFTT16DF          0
#    DF_1_DFT         400           1              2     DFTT11DFT     DFTT12DFT      76896
#    DF_1_DFT         500           1              2     DFTT11DFT     DFTT12DFT      88732
#    DF_1_DFT         800           2              3     DFTT12DFT     DFTT13DFT      82747
#    DF_1_DFT         900           2              3     DFTT12DFT     DFTT13DFT      65327
#    DF_1_DFT        1000           3              4     DFTT13DFT     DFTT14DFT     118223
#    DF_1_DFT        1100           3              4     DFTT13DFT     DFTT14DFT      13180
#    DF_1_DFT        1200           3              4     DFTT13DFT     DFTT14DFT       7860
#    DF_1_DFT        1300           4              5     DFTT14DFT     DFTT15DFT       2104
#    DF_1_DFT        1400           4              5     DFTT14DFT     DFTT15DFT        717
#    DF_1_DFT        1500           4              5     DFTT14DFT     DFTT15DFT      14520
#    DF_1_DFT        2500           5              6     DFTT15DFT     DFTT16DFT          2
#  HL_1_CABIN        1200           1              2   HLTT11CABIN   HLTT12CABIN     169848
#  HL_1_CABIN        1600           3              4   HLTT13CABIN   HLTT14CABIN      12162
#  HL_1_CABIN        1700           3              4   HLTT13CABIN   HLTT14CABIN       4363
#  HL_1_CABIN        1800           3              5   HLTT13CABIN   HLTT15CABIN       5762
#  HL_1_CABIN        1900           3              5   HLTT13CABIN   HLTT15CABIN       9302
#  HL_1_CABIN        2000           3              5   HLTT13CABIN   HLTT15CABIN      10826
#  HL_1_CABIN        2100           3              5   HLTT13CABIN   HLTT15CABIN       7074
#  HL_1_CABIN        2200           3              6   HLTT13CABIN   HLTT16CABIN       3838
#  HL_1_CABIN        2300           3              6   HLTT13CABIN   HLTT16CABIN       1344
#  HL_1_CABIN        2400           3              6   HLTT13CABIN   HLTT16CABIN       1590
#  HL_1_CABIN        2500           3              6   HLTT13CABIN   HLTT16CABIN       1381
#  HL_1_CABIN        2600           3              6   HLTT13CABIN   HLTT16CABIN       1152
#  HL_1_CABIN        2700           3              6   HLTT13CABIN   HLTT16CABIN       1431
#  HL_1_CABIN        2800           3              6   HLTT13CABIN   HLTT16CABIN       6992
#  HL_1_CABIN        2900           3              6   HLTT13CABIN   HLTT16CABIN       8175
#  HL_1_CABIN        3000           3              6   HLTT13CABIN   HLTT16CABIN        203
#  HL_1_CABIN        3100           3              6   HLTT13CABIN   HLTT16CABIN       1264
#  HL_1_CABIN        3200           3              6   HLTT13CABIN   HLTT16CABIN        169
#  HL_1_CABIN        3300           3              6   HLTT13CABIN   HLTT16CABIN        498
#  HL_1_CABIN        3400           3              6   HLTT13CABIN   HLTT16CABIN       1751
#  HL_1_CABIN        3500           3              6   HLTT13CABIN   HLTT16CABIN       2976
#  HL_1_CABIN        3600           3              6   HLTT13CABIN   HLTT16CABIN       1489
#  HL_1_CABIN        3700           3              6   HLTT13CABIN   HLTT16CABIN       1127
#  HL_1_CABIN        3800           3              6   HLTT13CABIN   HLTT16CABIN       2845
#  HL_1_CABIN        3900           3              6   HLTT13CABIN   HLTT16CABIN        619
#  HL_1_CABIN        4000           3              6   HLTT13CABIN   HLTT16CABIN       1654
#  HL_1_CABIN        4100           3              6   HLTT13CABIN   HLTT16CABIN       2137
#  HL_1_CABIN        4200           3              6   HLTT13CABIN   HLTT16CABIN        384
#  HL_1_CABIN        4300           3              6   HLTT13CABIN   HLTT16CABIN       2205
# HL_1_MEDIUM        3500           5              7  HLTT15MEDIUM  HLTT17MEDIUM      24150
# HL_1_MEDIUM        3600           5              7  HLTT15MEDIUM  HLTT17MEDIUM        267
# HL_1_MEDIUM        3700           5              8  HLTT15MEDIUM  HLTT18MEDIUM        409
# HL_1_MEDIUM        3800           5              8  HLTT15MEDIUM  HLTT18MEDIUM        387
# HL_1_MEDIUM        3900           5              8  HLTT15MEDIUM  HLTT18MEDIUM       1983
# HL_1_MEDIUM        4000           5              8  HLTT15MEDIUM  HLTT18MEDIUM        544
# HL_1_MEDIUM        4100           5              8  HLTT15MEDIUM  HLTT18MEDIUM        210
# HL_1_MEDIUM        4200           5              8  HLTT15MEDIUM  HLTT18MEDIUM       2821
# HL_1_MEDIUM        4300           5              8  HLTT15MEDIUM  HLTT18MEDIUM       1128
# HL_1_MEDIUM        4400           5              8  HLTT15MEDIUM  HLTT18MEDIUM       2135
# HL_1_MEDIUM        4500           5              8  HLTT15MEDIUM  HLTT18MEDIUM        506
# HL_1_MEDIUM        4600           5              8  HLTT15MEDIUM  HLTT18MEDIUM       1491
# HL_1_MEDIUM        4700           5              8  HLTT15MEDIUM  HLTT18MEDIUM       2570
# HL_1_MEDIUM        4800           5              8  HLTT15MEDIUM  HLTT18MEDIUM       2273
# HL_1_MEDIUM        4900           5              8  HLTT15MEDIUM  HLTT18MEDIUM       2095
# HL_1_MEDIUM        5000           6              8  HLTT16MEDIUM  HLTT18MEDIUM       2019
# HL_1_MEDIUM        5100           6              8  HLTT16MEDIUM  HLTT18MEDIUM       1136
# HL_1_MEDIUM        5200           6              8  HLTT16MEDIUM  HLTT18MEDIUM        882
# HL_1_MEDIUM        5300           6              8  HLTT16MEDIUM  HLTT18MEDIUM       2390
# HL_1_MEDIUM        5400           6              8  HLTT16MEDIUM  HLTT18MEDIUM       1113
# HL_1_MEDIUM        5500           6              8  HLTT16MEDIUM  HLTT18MEDIUM        392
# HL_1_MEDIUM        5600           7              8  HLTT17MEDIUM  HLTT18MEDIUM        722
# HL_1_MEDIUM        5700           7              8  HLTT17MEDIUM  HLTT18MEDIUM          0
# HL_1_MEDIUM        5800           7              8  HLTT17MEDIUM  HLTT18MEDIUM          7
#    HL_1_SO2        2600           1              2     HLTT11SO2     HLTT12SO2        869
#    HL_1_SO2        2700           1              2     HLTT11SO2     HLTT12SO2          0
#    HL_1_SO2        2800           1              2     HLTT11SO2     HLTT12SO2       8402
#    HL_1_SO2        2900           1              2     HLTT11SO2     HLTT12SO2      16297
#    HL_1_SO2        3000           2              3     HLTT12SO2     HLTT13SO2     105212
#    HL_1_SO2        3300           4              3     HLTT14SO2     HLTT13SO2      26591
#    HL_1_SO2        3400           5              3     HLTT15SO2     HLTT13SO2      30201
#    HL_1_SO2        3500           5              3     HLTT15SO2     HLTT13SO2        842
#    HL_1_SO2        3600           5              3     HLTT15SO2     HLTT13SO2       1401
#    HL_1_SO2        3700           5              3     HLTT15SO2     HLTT13SO2       1746
#    HL_1_SO2        3800           5              3     HLTT15SO2     HLTT13SO2        926
#    HL_1_SO2        3900           5              4     HLTT15SO2     HLTT14SO2        133
#    HL_1_SO2        4000           5              4     HLTT15SO2     HLTT14SO2       6518
#    HL_1_SO2        4100           5              4     HLTT15SO2     HLTT14SO2       1015
#    HL_1_SO2        4200           5              4     HLTT15SO2     HLTT14SO2       5082
#    HL_1_SO2        4300           5              4     HLTT15SO2     HLTT14SO2        163
#    HL_1_SO2        4400           5              4     HLTT15SO2     HLTT14SO2       1080
#    HL_1_SO2        4500           5              4     HLTT15SO2     HLTT14SO2       2760
#    HL_1_SO3        4400           1              2     HLTT11SO3     HLTT12SO3      44395
#    HL_1_SO3        4600           3              2     HLTT13SO3     HLTT12SO3      30124
#    HL_1_SO3        4700           4              2     HLTT14SO3     HLTT12SO3      30707
#    HL_1_SO3        4800           4              3     HLTT14SO3     HLTT13SO3        916
#    HL_1_SO3        4900           4              3     HLTT14SO3     HLTT13SO3      10471
#    HL_1_SO3        5000           4              3     HLTT14SO3     HLTT13SO3     170614
#    HL_1_SO3        5100           4              3     HLTT14SO3     HLTT13SO3      14665
#    HL_1_SO3        5500           5              4     HLTT15SO3     HLTT14SO3      11321
#    HL_1_SO3        5600           6              4     HLTT16SO3     HLTT14SO3      31247
#    HL_1_SO3        5700           6              5     HLTT16SO3     HLTT15SO3      40416
#    HL_1_SO3        5800           6              5     HLTT16SO3     HLTT15SO3       2687
#    HL_1_SO3        5900           6              5     HLTT16SO3     HLTT15SO3       6298
#    HL_1_SO3        6000           6              5     HLTT16SO3     HLTT15SO3       8556
#    HL_1_SO3        6500           6              5     HLTT16SO3     HLTT15SO3      10575
#    HL_1_SO3        7000           6              5     HLTT16SO3     HLTT15SO3       9908
#  SL_1_CABIN        1100           2              1   SLTT12CABIN   SLTT11CABIN      23439
#  SL_1_CABIN        1200           2              1   SLTT12CABIN   SLTT11CABIN      11210
#  SL_1_CABIN        1300           2              1   SLTT12CABIN   SLTT11CABIN       2568
#  SL_1_CABIN        1400           2              1   SLTT12CABIN   SLTT11CABIN       2210
#  SL_1_CABIN        1600           3              2   SLTT13CABIN   SLTT12CABIN      13267
#  SL_1_CABIN        1700           3              2   SLTT13CABIN   SLTT12CABIN       7920
#  SL_1_CABIN        1800           3              2   SLTT13CABIN   SLTT12CABIN       7468
#  SL_1_CABIN        1900           3              2   SLTT13CABIN   SLTT12CABIN       2754
#  SL_1_CABIN        2300           4              3   SLTT14CABIN   SLTT13CABIN       3146
#  SL_1_CABIN        2400           4              3   SLTT14CABIN   SLTT13CABIN       9637
#  SL_1_CABIN        2500           4              3   SLTT14CABIN   SLTT13CABIN       3877
#  SL_1_CABIN        3200           4              5   SLTT14CABIN   SLTT15CABIN        350
#  SL_1_CABIN        3300           4              5   SLTT14CABIN   SLTT15CABIN        589
#  SL_1_CABIN        3400           4              5   SLTT14CABIN   SLTT15CABIN        942
#  SL_1_CABIN        3500           4              5   SLTT14CABIN   SLTT15CABIN        316
#  SL_1_CABIN        3600           4              5   SLTT14CABIN   SLTT15CABIN       1016
#  SL_1_CABIN        3700           4              5   SLTT14CABIN   SLTT15CABIN        660
# SL_1_MEDIUM        2900           3              4  SLTT13MEDIUM  SLTT14MEDIUM      13353
# SL_1_MEDIUM        3000           3              4  SLTT13MEDIUM  SLTT14MEDIUM       2414
# SL_1_MEDIUM        3100           3              4  SLTT13MEDIUM  SLTT14MEDIUM       5037
# SL_1_MEDIUM        3200           3              4  SLTT13MEDIUM  SLTT14MEDIUM        605
# SL_1_MEDIUM        3300           3              4  SLTT13MEDIUM  SLTT14MEDIUM        777
# SL_1_MEDIUM        3400           3              4  SLTT13MEDIUM  SLTT14MEDIUM        424
# SL_1_MEDIUM        3500           3              4  SLTT13MEDIUM  SLTT14MEDIUM       4302
# SL_1_MEDIUM        3600           3              4  SLTT13MEDIUM  SLTT14MEDIUM       3716
# SL_1_MEDIUM        3800           4              5  SLTT14MEDIUM  SLTT15MEDIUM        987
# SL_1_MEDIUM        3900           4              5  SLTT14MEDIUM  SLTT15MEDIUM        218
# SL_1_MEDIUM        4000           4              5  SLTT14MEDIUM  SLTT15MEDIUM          2
# SL_1_MEDIUM        4100           4              5  SLTT14MEDIUM  SLTT15MEDIUM        165
# SL_1_MEDIUM        4300           4              5  SLTT14MEDIUM  SLTT15MEDIUM        390
# SL_1_MEDIUM        4400           4              5  SLTT14MEDIUM  SLTT15MEDIUM       1342
#    SL_1_SO2        2800           1              2     SLTT11SO2     SLTT12SO2          0
#    SL_1_SO2        2900           1              2     SLTT11SO2     SLTT12SO2      27377
#    SL_1_SO2        3100           3              2     SLTT13SO2     SLTT12SO2        136
#    SL_1_SO2        3200           3              2     SLTT13SO2     SLTT12SO2       8565
#    SL_1_SO2        3300           3              2     SLTT13SO2     SLTT12SO2       6165
#    SL_1_SO3        4600           1              2     SLTT11SO3     SLTT12SO3          0
#    SL_1_SO3        4700           1              2     SLTT11SO3     SLTT12SO3        277
#    SL_1_SO3        4800           1              2     SLTT11SO3     SLTT12SO3       2711
#    SL_1_SO3        5000           1              2     SLTT11SO3     SLTT12SO3        643
#    SL_1_SO3        5500           1              2     SLTT11SO3     SLTT12SO3       2942

# %% [markdown]
# ## 6. Save Validation Report

# %%
# Save full comparison table
try:
    eval_df.to_csv(f'{OUT}06_validation_detail.csv', index=False)
    print(f'OK Saved 06_validation_detail.csv  ({len(eval_df)} rows)')
except PermissionError:
    eval_df.to_csv(f'{OUT}06_validation_detail_new.csv', index=False)
    print(f'NOTE: saved as 06_validation_detail_new.csv — close the original in Excel first')

try:
    seg_res.to_csv(f'{OUT}06_validation_summary.csv', index=False)
    print(f'OK Saved 06_validation_summary.csv ({len(seg_res)} rows)')
except PermissionError:
    seg_res.to_csv(f'{OUT}06_validation_summary_new.csv', index=False)
    print('NOTE: saved as 06_validation_summary_new.csv — close the original in Excel first')
print()
print(f'FINAL: {n_match}/{n_total} bucket-rows correct ({n_match/n_total:.1%})')
print(f'       {qty_match/qty_total:.1%} of total qty correctly assigned')
# Out:
# ✓ Saved 06_validation_detail.csv  (568 rows)
# ✓ Saved 06_validation_summary.csv (14 rows)
#
# FINAL: 288/568 bucket-rows correct (50.7%)
#        26.5% of total qty correctly assigned
